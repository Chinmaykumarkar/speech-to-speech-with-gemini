# %%
import speech_recognition as sr
import os
import google.generativeai as genai
import pyttsx3


def speech_to_text():
    recognizer = sr.Recognizer()

    with sr.Microphone() as source:
        print("Say something:")
        audio = recognizer.listen(source)

    try:
        text = recognizer.recognize_google(audio)
        return text
    except sr.UnknownValueError:
        print("Could not understand audio")
    except sr.RequestError as e:
        print("Error; {0}".format(e))

transcribed_text=speech_to_text()
print(transcribed_text)
T_text = transcribed_text





genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 500,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)

chat_session = model.start_chat(
  history=[
  ]
)

response = chat_session.send_message(T_text)

print(response.text)

# Initialize the engine
engine = pyttsx3.init()

# Text to convert
text = response.text

# Convert text to speech
engine.say(text)
engine.runAndWait()
# Out:
# Say something:
# who is Narendra Modi
# ## Narendra Modi: Prime Minister of India
#
# Narendra Modi is the **current Prime Minister of India**, serving since 2014. He is a prominent figure in Indian politics, known for his strong leadership and development-centric approach. Here's a brief overview:
#
# **Background and Early Life:**
#
# * Born in 1950 in Vadnagar, Gujarat, India
# * Started his career as a tea seller before joining the Rashtriya Swayamsevak Sangh (RSS), a Hindu nationalist organization
# * Joined the Bharatiya Janata Party (BJP) and rose through the ranks
#
# **Political Career:**
#
# * Served as Chief Minister of Gujarat from 2001 to 2014, overseeing significant economic growth and development
# * Led the BJP to a landslide victory in the 2014 general election, becoming Prime Minister
# * Won a second term in 2019, becoming the first Prime Minister to win a consecutive majority in 30 years
#
# **Key Policies and Initiatives:**
#
# * **"Make in India":** Program to encourage domestic manufacturing and attract foreign investment
# * **"Swachh Bharat Abhiyan":** National cleanliness campaign
# * **"Digital India":** Initiative to promote digital literacy and infrastructure
# * **"Skill India":** Program to improve vocational skills training
# * **"Housing for All":** Scheme to provide affordable housing
#
# **Strengths and Criticisms:**
#
# **Strengths:**
#
# * Strong leadership and charisma
# * Focus on economic development and infrastructure
# * Effective communicator and campaigner
#
# **Criticisms:**
#
# * Accused of authoritarian tendencies and suppression of dissent
# * Role in the 2002 Gujarat riots remains controversial
# * Critics argue that his policies favor certain groups and neglect others
#
# **International Profile:**
#
# * Known for his strong diplomatic ties with several countries, including the US, Japan, and Australia
# * Played a key role in promoting India's global influence
#
# **Legacy:**
#
# Narendra Modi is a transformative figure in Indian politics. His economic reforms and focus on infrastructure development have had a significant impact on the country. However, his policies and leadership style continue to be debated and scrutinized. His legacy will be shaped by the long-term impact of his policies and the nature of his political legacy.
#
# This is a brief overview of Narendra Modi. There is much more to learn about his life, policies, and impact on India. Further
